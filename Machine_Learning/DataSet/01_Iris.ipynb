# %%
import pandas as pd
import numpy as np
from sklearn.model.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\adity\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3667, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\adity\AppData\Local\Temp\ipykernel_13596\4210843160.py", line 3, in <module>
#     from sklearn.model.ensemble import RandomForestClassifier
# ModuleNotFoundError: No module named 'sklearn.model'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\adity\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#         etype, value, tb, tb_offset=tb_offset
#     )
# ...

# %%
df=pd.read_csv('Iris.csv')
df.head()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\adity\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3667, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\adity\AppData\Local\Temp\ipykernel_15668\273331677.py", line 1, in <module>
#     df=pd.read_csv('Iris.csv')
#        ^^
# NameError: name 'pd' is not defined. Did you mean: 'id'?
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\adity\miniconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#         etype, value, tb, tb_offset=tb_offset
#     )
#   File "c:\Users\adity\miniconda3\Lib\site-packages\IPython\core\ultratb.py", line 1182, in structured_traceback
# ...
