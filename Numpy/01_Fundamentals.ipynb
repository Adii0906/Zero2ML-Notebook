# %% [markdown]
# # Numpy is used for numerical computations in Python.
# # its array structures and mathematical functions make it a powerful tool for data analysis and scientific computing.

# %%
import numpy as np
# ------ Creating arrays ------
a = np.array([1, 2, 3]) # 1D array
b = np.array([[1, 2], [3, 4]]) # 2D array
zeros = np.zeros((2, 3)) 
ones = np.ones((3, 3))
random_vals = np.random.rand(2, 2)
range_vals = np.arange(0, 10, 2)

print("Array a:", a)
print("2D Array b:\n", b)
# Out:
# Array a: [1 2 3]
# 2D Array b:
#  [[1 2]
#  [3 4]]

# %%
# ------ Summary statistics ------
print("Mean:", np.mean(arr))
print("Std:", np.std(arr))
print("Min:", np.min(arr))
print("Max:", np.max(arr))
# Out:
# Mean: 2.5
# Std: 1.118033988749895
# Min: 1
# Max: 4

# %%
# ------ Basic math operations ------
arr = np.array([1, 2, 3, 4])
print("Add:", arr + 2)
print("Multiply:", arr * 2)
print("Square:", arr ** 2)
# Out:
# Add: [3 4 5 6]
# Multiply: [2 4 6 8]
# Square: [ 1  4  9 16]
